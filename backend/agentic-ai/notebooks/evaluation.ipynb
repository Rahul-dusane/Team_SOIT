# %% [markdown]
# # HireLens — Evaluation Notebook (Member 2)
# Quantitative evaluation of candidate ranking against human ground truth ratings across 30 candidate-job pairs (10 candidates x 3 jobs).

# %%
import sys, os
backend_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if backend_dir not in sys.path:
    sys.path.insert(0, backend_dir)

from contracts.candidate import CandidateProfile, CandidateSkill
from contracts.job import JobProfile
from matching.batch_matcher import match_all
from matching.evaluation import evaluate_batch_results
from verify_member2 import generate_sample_dataset

candidates, jobs = generate_sample_dataset()
batch_results = match_all(candidates, jobs)
eval_df = evaluate_batch_results(batch_results)
eval_df
